# %%
pip install pyconll
# Out:
# Collecting pyconll
#   Downloading pyconll-3.2.0-py3-none-any.whl.metadata (8.0 kB)
# Downloading pyconll-3.2.0-py3-none-any.whl (27 kB)
# Installing collected packages: pyconll
# Successfully installed pyconll-3.2.0

# %%
import pyconll
from collections import defaultdict

def find_redup_relations(conll_file_path):
    """
    Finds all relations where a token has 'compound:redup' as its dependent
    and counts the frequency of each head relation type.

    Args:
        conll_file_path: Path to the CoNLL-U file to analyze.

    Returns:
        A tuple containing:
        - A dictionary mapping head tokens to their redup dependents and relations
        - A dictionary counting occurrences of each head relation type
    """
    # Load the CoNLL-U file
    corpus = pyconll.load_from_file(conll_file_path)

    results = {}
    relation_counts = defaultdict(int)

    for sentence in corpus:
        for token in sentence:
            # Skip multiword tokens (they don't participate in dependencies)
            if '-' in token.id:
                continue

            # Check if this token has any 'compound:redup' dependents
            redup_dependents = [dep for dep in sentence if
                               dep.head == token.id and
                               dep.deprel == "compound:redup"]

            if redup_dependents:
                # Get the head of this token (if it has one)
                head_token = None
                if token.head != "0":  # '0' means no head
                    try:
                        head_token = sentence[token.head]
                    except KeyError:
                        head_token = None

                # Store the information
                results[token] = {
                    'head': head_token,
                    'head_relation': token.deprel if token.head != "0" else "root",
                    'redup_dependents': redup_dependents
                }

                # Count the relation type
                relation = token.deprel if token.head != "0" else "root"
                relation_counts[relation] += 1

    return results, relation_counts

def print_results(results, relation_counts):
    """
    Prints the results in a readable format.
    """
    # Print relation counts first
    print("\nRELATION TYPE COUNTS:")
    print("---------------------")
    for relation, count in sorted(relation_counts.items(), key=lambda x: x[1], reverse=True):
        print(f"{relation}: {count}")

    # Then print detailed information
    print("\nDETAILED INFORMATION:")
    print("---------------------")
    for token, info in results.items():
        print(f"Token: {token.form} (ID: {token.id}, Lemma: {token.lemma})")
        print(f"  - Relation to head: {info['head_relation']}")
        if info['head']:
            print(f"  - Head token: {info['head'].form} (ID: {info['head'].id}, Lemma: {info['head'].lemma})")
        print("  - Reduplication dependents:")
        for dep in info['redup_dependents']:
            print(f"    - {dep.form} (ID: {dep.id}, Lemma: {dep.lemma})")
        print("-" * 40)

# Example usage
if __name__ == "__main__":
    # Replace with your actual CoNLL-U file path
    conll_file = "/content/nutukakadar-copy.conllu"

    try:
        relations, counts = find_redup_relations(conll_file)
        print_results(relations, counts)
        print(f"\nFound {len(relations)} tokens with compound:redup dependents.")
    except Exception as e:
        print(f"Error processing file: {e}")
# Out:
# RELATION TYPE COUNTS:
# ---------------------
# advmod: 18
# advcl: 13
# amod: 6
# compound:lvc: 3
# ccomp: 2
#
# DETAILED INFORMATION:
# ---------------------
# Token: edib (ID: 7, Lemma: et)
#   - Relation to head: compound:lvc
#   - Head token: celb-i (ID: 5, Lemma: celb-i)
#   - Reduplication dependents:
#     - etmediğini (ID: 8, Lemma: et)
# ----------------------------------------
# Token: yavaş (ID: 10, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: uyuşturuyordu (ID: 16, Lemma: uyuş)
#   - Reduplication dependents:
#     - yavaş (ID: 11, Lemma: yavaş)
# ----------------------------------------
# Token: korka (ID: 28, Lemma: kork)
#   - Relation to head: advcl
#   - Head token: fırlayan (ID: 30, Lemma: fırla)
#   - Reduplication dependents:
#     - korka (ID: 29, Lemma: kork)
# ----------------------------------------
# Token: doğar (ID: 15, Lemma: doğ)
#   - Relation to head: advcl
#   - Head token: acıtıyor (ID: 29, Lemma: acı)
#   - Reduplication dependents:
#     - doğmaz (ID: 16, Lemma: doğ)
# ----------------------------------------
# Token: girilir (ID: 4, Lemma: gir)
#   - Relation to head: advcl
#   - Head token: dokunur (ID: 12, Lemma: dokun)
#   - Reduplication dependents:
#     - girilmez (ID: 5, Lemma: gir)
# ----------------------------------------
# Token: inleye (ID: 3, Lemma: inle)
#   - Relation to head: advcl
#   - Head token: kalkan (ID: 6, Lemma: kalk)
#   - Reduplication dependents:
#     - inleye (ID: 4, Lemma: inle)
# ----------------------------------------
# Token: hemen (ID: 9, Lemma: hemen)
#   - Relation to head: advmod
#   - Head token: tenâvül (ID: 12, Lemma: tenâvül)
#   - Reduplication dependents:
#     - hemen (ID: 10, Lemma: hemen)
# ----------------------------------------
# Token: yavaş (ID: 17, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: kaldırıyor (ID: 19, Lemma: kaldır)
#   - Reduplication dependents:
#     - yavaş (ID: 18, Lemma: yavaş)
# ----------------------------------------
# Token: ağır (ID: 5, Lemma: ağır)
#   - Relation to head: advmod
#   - Head token: geçen (ID: 7, Lemma: geç)
#   - Reduplication dependents:
#     - ağır (ID: 6, Lemma: ağır)
# ----------------------------------------
# Token: sulana (ID: 5, Lemma: sulan)
#   - Relation to head: advcl
#   - Head token: birikib (ID: 7, Lemma: birik)
#   - Reduplication dependents:
#     - sulana (ID: 6, Lemma: sulan)
# ----------------------------------------
# Token: titreye (ID: 13, Lemma: titre)
#   - Relation to head: advcl
#   - Head token: batırıyor (ID: 15, Lemma: batır)
#   - Reduplication dependents:
#     - titreye (ID: 14, Lemma: titre)
# ----------------------------------------
# Token: yavaş (ID: 8, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: çıktı (ID: 11, Lemma: çık)
#   - Reduplication dependents:
#     - yavaş (ID: 9, Lemma: yavaş)
# ----------------------------------------
# Token: güzel (ID: 30, Lemma: güzel)
#   - Relation to head: amod
#   - Head token: misaller (ID: 32, Lemma: misal)
#   - Reduplication dependents:
#     - güzel (ID: 31, Lemma: güzel)
# ----------------------------------------
# Token: hayran (ID: 5, Lemma: hayran)
#   - Relation to head: advmod
#   - Head token: nasb-ı (ID: 9, Lemma: nasb)
#   - Reduplication dependents:
#     - hayran (ID: 6, Lemma: hayran)
# ----------------------------------------
# Token: Tombul (ID: 1, Lemma: tombul)
#   - Relation to head: amod
#   - Head token: ellerini (ID: 3, Lemma: el)
#   - Reduplication dependents:
#     - tombul (ID: 2, Lemma: tombul)
# ----------------------------------------
# Token: keyifli (ID: 9, Lemma: keyifli)
#   - Relation to head: advmod
#   - Head token: sallayıp (ID: 11, Lemma: salla)
#   - Reduplication dependents:
#     - keyifli (ID: 10, Lemma: keyifli)
# ----------------------------------------
# Token: dinlene (ID: 11, Lemma: dinlen)
#   - Relation to head: advcl
#   - Head token: yürümeğe (ID: 14, Lemma: yürü)
#   - Reduplication dependents:
#     - soluya (ID: 13, Lemma: solu)
# ----------------------------------------
# Token: yavaş (ID: 2, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: kalkıyordu (ID: 4, Lemma: kalk)
#   - Reduplication dependents:
#     - yavaş (ID: 3, Lemma: yavaş)
# ----------------------------------------
# Token: yavaş (ID: 7, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: aradı (ID: 11, Lemma: ara)
#   - Reduplication dependents:
#     - yavaş (ID: 8, Lemma: yavaş)
# ----------------------------------------
# Token: yavaş (ID: 17, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: kaldırarak (ID: 20, Lemma: kaldır)
#   - Reduplication dependents:
#     - yavaş (ID: 18, Lemma: yavaş)
# ----------------------------------------
# Token: mini (ID: 8, Lemma: mini)
#   - Relation to head: amod
#   - Head token: Jân'ın (ID: 10, Lemma: Jân)
#   - Reduplication dependents:
#     - mini (ID: 9, Lemma: mini)
# ----------------------------------------
# Token: süzüle (ID: 27, Lemma: süz)
#   - Relation to head: advcl
#   - Head token: yuvarlandı (ID: 31, Lemma: yuvarlan)
#   - Reduplication dependents:
#     - süzüle (ID: 28, Lemma: süz)
# ----------------------------------------
# Token: olur (ID: 9, Lemma: ol)
#   - Relation to head: compound:lvc
#   - Head token: hâsıl (ID: 8, Lemma: hâsıl)
#   - Reduplication dependents:
#     - olmaz (ID: 10, Lemma: ol)
# ----------------------------------------
# Token: mini (ID: 30, Lemma: mini)
#   - Relation to head: amod
#   - Head token: halkı (ID: 33, Lemma: halk)
#   - Reduplication dependents:
#     - mini (ID: 31, Lemma: mini)
# ----------------------------------------
# Token: kendi (ID: 24, Lemma: kendi)
#   - Relation to head: advmod
#   - Head token: düşen (ID: 26, Lemma: düş)
#   - Reduplication dependents:
#     - kendine (ID: 25, Lemma: kendi)
# ----------------------------------------
# Token: girer (ID: 2, Lemma: gir)
#   - Relation to head: advcl
#   - Head token: tahriş (ID: 9, Lemma: tahriş)
#   - Reduplication dependents:
#     - girmez (ID: 3, Lemma: gir)
# ----------------------------------------
# Token: çıkar (ID: 26, Lemma: çık)
#   - Relation to head: advcl
#   - Head token: kopmuş (ID: 33, Lemma: kop)
#   - Reduplication dependents:
#     - çıkmaz (ID: 27, Lemma: çık)
# ----------------------------------------
# Token: titreye (ID: 5, Lemma: titre)
#   - Relation to head: advcl
#   - Head token: götürmekte (ID: 10, Lemma: götür)
#   - Reduplication dependents:
#     - titreye (ID: 6, Lemma: titre)
# ----------------------------------------
# Token: parıl (ID: 18, Lemma: parıl)
#   - Relation to head: advmod
#   - Head token: parlayarak (ID: 20, Lemma: parla)
#   - Reduplication dependents:
#     - parıl (ID: 19, Lemma: parıl)
# ----------------------------------------
# Token: parça (ID: 12, Lemma: parça)
#   - Relation to head: advmod
#   - Head token: olmuş (ID: 14, Lemma: ol)
#   - Reduplication dependents:
#     - parça (ID: 13, Lemma: parça)
# ----------------------------------------
# Token: açılır (ID: 10, Lemma: aç)
#   - Relation to head: amod
#   - Head token: iskemleye (ID: 13, Lemma: iskemle)
#   - Reduplication dependents:
#     - kapanır (ID: 11, Lemma: kapa)
# ----------------------------------------
# Token: Karşı (ID: 1, Lemma: karşı)
#   - Relation to head: advmod
#   - Head token: oturmuş (ID: 3, Lemma: otur)
#   - Reduplication dependents:
#     - karşıya (ID: 2, Lemma: karşı)
# ----------------------------------------
# Token: gelir (ID: 3, Lemma: gel)
#   - Relation to head: advcl
#   - Head token: mecbur (ID: 8, Lemma: mecbur)
#   - Reduplication dependents:
#     - gelmez (ID: 4, Lemma: gel)
# ----------------------------------------
# Token: olursa (ID: 6, Lemma: ol)
#   - Relation to head: ccomp
#   - Head token: kesb-i (ID: 22, Lemma: kesb)
#   - Reduplication dependents:
#     - olsun (ID: 7, Lemma: ol)
# ----------------------------------------
# Token: olursa (ID: 10, Lemma: ol)
#   - Relation to head: ccomp
#   - Head token: mücadele (ID: 19, Lemma: mücadele)
#   - Reduplication dependents:
#     - olsun (ID: 11, Lemma: ol)
# ----------------------------------------
# Token: kademe (ID: 18, Lemma: kademe)
#   - Relation to head: advmod
#   - Head token: yürüyerek (ID: 20, Lemma: yürü)
#   - Reduplication dependents:
#     - kademe (ID: 19, Lemma: kademe)
# ----------------------------------------
# Token: safha (ID: 22, Lemma: safha)
#   - Relation to head: advmod
#   - Head token: tahakkuk (ID: 35, Lemma: tahakkuk)
#   - Reduplication dependents:
#     - safha (ID: 23, Lemma: safha)
# ----------------------------------------
# Token: zaman (ID: 18, Lemma: zaman)
#   - Relation to head: advmod
#   - Head token: ihtilâflar (ID: 29, Lemma: ihtilâf)
#   - Reduplication dependents:
#     - zaman (ID: 19, Lemma: zaman)
# ----------------------------------------
# Token: birer (ID: 18, Lemma: bir)
#   - Relation to head: advmod
#   - Head token: işaret (ID: 20, Lemma: işaret)
#   - Reduplication dependents:
#     - birer (ID: 19, Lemma: bir)
# ----------------------------------------
# Token: olup (ID: 13, Lemma: ol)
#   - Relation to head: compound:lvc
#   - Head token: muvaffak (ID: 12, Lemma: muvaffak)
#   - Reduplication dependents:
#     - olmayacağını (ID: 14, Lemma: olm)
# ----------------------------------------
# Token: mini (ID: 2, Lemma: mini)
#   - Relation to head: amod
#   - Head token: husarlar (ID: 4, Lemma: husar)
#   - Reduplication dependents:
#     - mini (ID: 3, Lemma: mini)
# ----------------------------------------
# Token: seve (ID: 3, Lemma: seve)
#   - Relation to head: advcl
#   - Head token: söyleyerek (ID: 6, Lemma: söyle)
#   - Reduplication dependents:
#     - seve (ID: 4, Lemma: seve)
# ----------------------------------------
#
# Found 42 tokens with compound:redup dependents.

# %%
import pyconll
from collections import defaultdict

def find_redup_relations(conll_file_path):
    """
    Finds all relations where a token has 'compound:redup' as its dependent
    and counts the frequency of each head relation type.

    Args:
        conll_file_path: Path to the CoNLL-U file to analyze.

    Returns:
        A tuple containing:
        - A dictionary mapping head tokens to their redup dependents and relations
        - A dictionary counting occurrences of each head relation type
    """
    # Load the CoNLL-U file
    corpus = pyconll.load_from_file(conll_file_path)

    results = {}
    relation_counts = defaultdict(int)

    for sentence in corpus:
        for token in sentence:
            # Skip multiword tokens (they don't participate in dependencies)
            if '-' in token.id:
                continue

            # Check if this token has any 'compound:redup' dependents
            redup_dependents = [dep for dep in sentence if
                               dep.head == token.id and
                               dep.deprel == "compound:redup"]

            if redup_dependents:
                # Get the head of this token (if it has one)
                head_token = None
                if token.head != "0":  # '0' means no head
                    try:
                        head_token = sentence[token.head]
                    except KeyError:
                        head_token = None

                # Store the information
                results[token] = {
                    'head': head_token,
                    'head_relation': token.deprel if token.head != "0" else "root",
                    'redup_dependents': redup_dependents
                }

                # Count the relation type
                relation = token.deprel if token.head != "0" else "root"
                relation_counts[relation] += 1

    return results, relation_counts

def print_results(results, relation_counts):
    """
    Prints the results in a readable format.
    """
    # Print relation counts first
    print("\nRELATION TYPE COUNTS:")
    print("---------------------")
    for relation, count in sorted(relation_counts.items(), key=lambda x: x[1], reverse=True):
        print(f"{relation}: {count}")

    # Then print detailed information
    print("\nDETAILED INFORMATION:")
    print("---------------------")
    for token, info in results.items():
        print(f"Token: {token.form} (ID: {token.id}, Lemma: {token.lemma})")
        print(f"  - Relation to head: {info['head_relation']}")
        if info['head']:
            print(f"  - Head token: {info['head'].form} (ID: {info['head'].id}, Lemma: {info['head'].lemma})")
        print("  - Reduplication dependents:")
        for dep in info['redup_dependents']:
            print(f"    - {dep.form} (ID: {dep.id}, Lemma: {dep.lemma})")
        print("-" * 40)

# Example usage
if __name__ == "__main__":
    # Replace with your actual CoNLL-U file path
    conll_file = "/content/nutukakadar.conllu"

    try:
        relations, counts = find_redup_relations(conll_file)
        print_results(relations, counts)
        print(f"\nFound {len(relations)} tokens with compound:redup dependents.")
    except Exception as e:
        print(f"Error processing file: {e}")
# Out:
# RELATION TYPE COUNTS:
# ---------------------
# advmod: 18
# advcl: 14
# amod: 5
# compound:lvc: 3
# obj: 1
# acl: 1
#
# DETAILED INFORMATION:
# ---------------------
# Token: edib (ID: 7, Lemma: et)
#   - Relation to head: compound:lvc
#   - Head token: celb-i (ID: 5, Lemma: celb-i)
#   - Reduplication dependents:
#     - etmediğini (ID: 8, Lemma: et)
# ----------------------------------------
# Token: yavaş (ID: 10, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: uyuşturuyordu (ID: 16, Lemma: uyuş)
#   - Reduplication dependents:
#     - yavaş (ID: 11, Lemma: yavaş)
# ----------------------------------------
# Token: korka (ID: 28, Lemma: kork)
#   - Relation to head: advcl
#   - Head token: fırlayan (ID: 30, Lemma: fırla)
#   - Reduplication dependents:
#     - korka (ID: 29, Lemma: kork)
# ----------------------------------------
# Token: doğar (ID: 15, Lemma: doğ)
#   - Relation to head: advcl
#   - Head token: acıtıyor (ID: 29, Lemma: acı)
#   - Reduplication dependents:
#     - doğmaz (ID: 16, Lemma: doğ)
# ----------------------------------------
# Token: girilir (ID: 4, Lemma: gir)
#   - Relation to head: advcl
#   - Head token: dokunur (ID: 12, Lemma: dokun)
#   - Reduplication dependents:
#     - girilmez (ID: 5, Lemma: gir)
# ----------------------------------------
# Token: inleye (ID: 3, Lemma: inle)
#   - Relation to head: advcl
#   - Head token: kalkan (ID: 6, Lemma: kalk)
#   - Reduplication dependents:
#     - inleye (ID: 4, Lemma: inle)
# ----------------------------------------
# Token: hemen (ID: 9, Lemma: hemen)
#   - Relation to head: advmod
#   - Head token: tenâvül (ID: 12, Lemma: tenâvül)
#   - Reduplication dependents:
#     - hemen (ID: 10, Lemma: hemen)
# ----------------------------------------
# Token: yavaş (ID: 17, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: kaldırıyor (ID: 19, Lemma: kaldır)
#   - Reduplication dependents:
#     - yavaş (ID: 18, Lemma: yavaş)
# ----------------------------------------
# Token: ağır (ID: 5, Lemma: ağır)
#   - Relation to head: advmod
#   - Head token: geçen (ID: 7, Lemma: geç)
#   - Reduplication dependents:
#     - ağır (ID: 6, Lemma: ağır)
# ----------------------------------------
# Token: sulana (ID: 5, Lemma: sulan)
#   - Relation to head: advcl
#   - Head token: birikib (ID: 7, Lemma: birik)
#   - Reduplication dependents:
#     - sulana (ID: 6, Lemma: sulan)
# ----------------------------------------
# Token: titreye (ID: 13, Lemma: titre)
#   - Relation to head: advcl
#   - Head token: batırıyor (ID: 15, Lemma: batır)
#   - Reduplication dependents:
#     - titreye (ID: 14, Lemma: titre)
# ----------------------------------------
# Token: yavaş (ID: 8, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: çıktı (ID: 11, Lemma: çık)
#   - Reduplication dependents:
#     - yavaş (ID: 9, Lemma: yavaş)
# ----------------------------------------
# Token: güzel (ID: 30, Lemma: güzel)
#   - Relation to head: amod
#   - Head token: misaller (ID: 32, Lemma: misal)
#   - Reduplication dependents:
#     - güzel (ID: 31, Lemma: güzel)
# ----------------------------------------
# Token: hayran (ID: 5, Lemma: hayran)
#   - Relation to head: advmod
#   - Head token: nasb-ı (ID: 9, Lemma: nasb)
#   - Reduplication dependents:
#     - hayran (ID: 6, Lemma: hayran)
# ----------------------------------------
# Token: Tombul (ID: 1, Lemma: tombul)
#   - Relation to head: amod
#   - Head token: ellerini (ID: 3, Lemma: el)
#   - Reduplication dependents:
#     - tombul (ID: 2, Lemma: tombul)
# ----------------------------------------
# Token: keyifli (ID: 9, Lemma: keyifli)
#   - Relation to head: advmod
#   - Head token: sallayıp (ID: 11, Lemma: salla)
#   - Reduplication dependents:
#     - keyifli (ID: 10, Lemma: keyifli)
# ----------------------------------------
# Token: dinlene (ID: 11, Lemma: dinlen)
#   - Relation to head: advcl
#   - Head token: yürümeğe (ID: 14, Lemma: yürü)
#   - Reduplication dependents:
#     - soluya (ID: 13, Lemma: solu)
# ----------------------------------------
# Token: yavaş (ID: 2, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: kalkıyordu (ID: 4, Lemma: kalk)
#   - Reduplication dependents:
#     - yavaş (ID: 3, Lemma: yavaş)
# ----------------------------------------
# Token: yavaş (ID: 7, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: aradı (ID: 11, Lemma: ara)
#   - Reduplication dependents:
#     - yavaş (ID: 8, Lemma: yavaş)
# ----------------------------------------
# Token: yavaş (ID: 17, Lemma: yavaş)
#   - Relation to head: advmod
#   - Head token: kaldırarak (ID: 20, Lemma: kaldır)
#   - Reduplication dependents:
#     - yavaş (ID: 18, Lemma: yavaş)
# ----------------------------------------
# Token: mini (ID: 8, Lemma: mini)
#   - Relation to head: amod
#   - Head token: Jân'ın (ID: 10, Lemma: Jân)
#   - Reduplication dependents:
#     - mini (ID: 9, Lemma: mini)
# ----------------------------------------
# Token: süzüle (ID: 27, Lemma: süz)
#   - Relation to head: advcl
#   - Head token: yuvarlandı (ID: 31, Lemma: yuvarlan)
#   - Reduplication dependents:
#     - süzüle (ID: 28, Lemma: süz)
# ----------------------------------------
# Token: olur (ID: 9, Lemma: ol)
#   - Relation to head: compound:lvc
#   - Head token: hâsıl (ID: 8, Lemma: hâsıl)
#   - Reduplication dependents:
#     - olmaz (ID: 10, Lemma: ol)
# ----------------------------------------
# Token: mini (ID: 30, Lemma: mini)
#   - Relation to head: amod
#   - Head token: halkı (ID: 33, Lemma: halk)
#   - Reduplication dependents:
#     - mini (ID: 31, Lemma: mini)
# ----------------------------------------
# Token: kendi (ID: 24, Lemma: kendi)
#   - Relation to head: advmod
#   - Head token: düşen (ID: 26, Lemma: düş)
#   - Reduplication dependents:
#     - kendine (ID: 25, Lemma: kendi)
# ----------------------------------------
# Token: girer (ID: 2, Lemma: gir)
#   - Relation to head: advcl
#   - Head token: tahriş (ID: 9, Lemma: tahriş)
#   - Reduplication dependents:
#     - girmez (ID: 3, Lemma: gir)
# ----------------------------------------
# Token: çıkar (ID: 26, Lemma: çık)
#   - Relation to head: advcl
#   - Head token: kopmuş (ID: 33, Lemma: kop)
#   - Reduplication dependents:
#     - çıkmaz (ID: 27, Lemma: çık)
# ----------------------------------------
# Token: titreye (ID: 5, Lemma: titre)
#   - Relation to head: advcl
#   - Head token: götürmekte (ID: 10, Lemma: götür)
#   - Reduplication dependents:
#     - titreye (ID: 6, Lemma: titre)
# ----------------------------------------
# Token: parıl (ID: 18, Lemma: parıl)
#   - Relation to head: advmod
#   - Head token: parlayarak (ID: 20, Lemma: parla)
#   - Reduplication dependents:
#     - parıl (ID: 19, Lemma: parıl)
# ----------------------------------------
# Token: parça (ID: 12, Lemma: parça)
#   - Relation to head: obj
#   - Head token: olmuş (ID: 14, Lemma: ol)
#   - Reduplication dependents:
#     - parça (ID: 13, Lemma: parça)
# ----------------------------------------
# Token: açılır (ID: 10, Lemma: aç)
#   - Relation to head: acl
#   - Head token: iskemleye (ID: 13, Lemma: iskemle)
#   - Reduplication dependents:
#     - kapanır (ID: 11, Lemma: kapa)
# ----------------------------------------
# Token: Karşı (ID: 1, Lemma: karşı)
#   - Relation to head: advmod
#   - Head token: oturmuş (ID: 3, Lemma: otur)
#   - Reduplication dependents:
#     - karşıya (ID: 2, Lemma: karşı)
# ----------------------------------------
# Token: gelir (ID: 3, Lemma: gel)
#   - Relation to head: advcl
#   - Head token: mecbur (ID: 8, Lemma: mecbur)
#   - Reduplication dependents:
#     - gelmez (ID: 4, Lemma: gel)
# ----------------------------------------
# Token: olursa (ID: 6, Lemma: ol)
#   - Relation to head: advcl
#   - Head token: kesb-i (ID: 22, Lemma: kesb)
#   - Reduplication dependents:
#     - olsun (ID: 7, Lemma: ol)
# ----------------------------------------
# Token: olursa (ID: 10, Lemma: ol)
#   - Relation to head: advcl
#   - Head token: mücadele (ID: 19, Lemma: mücadele)
#   - Reduplication dependents:
#     - olsun (ID: 11, Lemma: ol)
# ----------------------------------------
# Token: kademe (ID: 18, Lemma: kademe)
#   - Relation to head: advmod
#   - Head token: yürüyerek (ID: 20, Lemma: yürü)
#   - Reduplication dependents:
#     - kademe (ID: 19, Lemma: kademe)
# ----------------------------------------
# Token: safha (ID: 22, Lemma: safha)
#   - Relation to head: advmod
#   - Head token: tahakkuk (ID: 35, Lemma: tahakkuk)
#   - Reduplication dependents:
#     - safha (ID: 23, Lemma: safha)
# ----------------------------------------
# Token: zaman (ID: 18, Lemma: zaman)
#   - Relation to head: advmod
#   - Head token: ihtilâflar (ID: 29, Lemma: ihtilâf)
#   - Reduplication dependents:
#     - zaman (ID: 19, Lemma: zaman)
# ----------------------------------------
# Token: birer (ID: 18, Lemma: bir)
#   - Relation to head: advmod
#   - Head token: işaret (ID: 20, Lemma: işaret)
#   - Reduplication dependents:
#     - birer (ID: 19, Lemma: bir)
# ----------------------------------------
# Token: olup (ID: 13, Lemma: ol)
#   - Relation to head: compound:lvc
#   - Head token: muvaffak (ID: 12, Lemma: muvaffak)
#   - Reduplication dependents:
#     - olmayacağını (ID: 14, Lemma: olm)
# ----------------------------------------
# Token: mini (ID: 2, Lemma: mini)
#   - Relation to head: amod
#   - Head token: husarlar (ID: 4, Lemma: husar)
#   - Reduplication dependents:
#     - mini (ID: 3, Lemma: mini)
# ----------------------------------------
# Token: seve (ID: 3, Lemma: seve)
#   - Relation to head: advmod
#   - Head token: söyleyerek (ID: 6, Lemma: söyle)
#   - Reduplication dependents:
#     - seve (ID: 4, Lemma: seve)
# ----------------------------------------
#
# Found 42 tokens with compound:redup dependents.
